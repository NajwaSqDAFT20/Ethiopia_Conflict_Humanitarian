# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas_profiling

# %%
ls
# Out:
# ACLED-Data-Columns_Quick-Reference_FINAL.pdf
# ACLED1900-01-01-2020-12-09-Ethiopia.csv
# ACLED_API_test.ipynb
# ACLED_Codebook_2019FINAL_pbl.pdf
# ACLED_User-Guide-for-Humanitarians_2019FINAL.pdf
# AcledEvents.xls
# conflict_data_eth.csv
# conflict_data_eth_check.csv
# errors.log
# quick analysis conflict data.ipynb

# %%
df_conflict= pd.read_csv("conflict_data_eth.csv")
df_conflict.head()
# Out:
#      data_id    iso event_id_cnty  event_id_no_cnty      event_date  \
# 0        NaN    NaN   #event+code               NaN  #date+occurred
# 1  7330171.0  231.0       ETH5780            5780.0      2020-12-04
# 2  7329896.0  231.0       ETH5779            5779.0      2020-12-03
# 3  7329829.0  231.0       ETH5777            5777.0      2020-12-02
# 4  7329897.0  231.0       ETH5778            5778.0      2020-12-02
#
#          year  time_precision                  event_type sub_event_type  \
# 0  #date+year             NaN                 #event+type            NaN
# 1        2020             2.0  Violence against civilians         Attack
# 2        2020             1.0                     Battles    Armed clash
# 3        2020             1.0  Violence against civilians         Attack
# 4        2020             1.0                     Battles    Armed clash
#
#                                    actor1  ...       location  latitude  \
# ...

# %%
df_conflict.shape
# Out:
# (5660, 31)

# %%
# event identification columns are the first 4
#iso is a number to events where it has happened. useful to join tables

# %%
#df_conflict.profile_report()

# %%
df_conflict.describe()
# Out:
#             data_id     iso  event_id_no_cnty  time_precision       inter1  \
# count  5.659000e+03  5659.0       5659.000000     5659.000000  5659.000000
# mean   6.100061e+06   231.0       2899.265241        1.130588     3.090475
# std    7.458247e+05     0.0       1672.246891        0.405532     2.180105
# min    4.554792e+06   231.0          1.000000        1.000000     1.000000
# 25%    5.269476e+06   231.0       1446.500000        1.000000     1.000000
# 50%    6.409598e+06   231.0       2904.000000        1.000000     2.000000
# 75%    6.411200e+06   231.0       4351.500000        1.000000     6.000000
# max    7.330178e+06   231.0       5781.000000        3.000000     8.000000
#
#             inter2  interaction  geo_precision     timestamp
# count  5659.000000  5659.000000    5659.000000  5.659000e+03
# mean      3.015197    29.978972       1.382046  1.572540e+09
# std       2.788804    20.054981       0.554874  1.399942e+07
# ...
