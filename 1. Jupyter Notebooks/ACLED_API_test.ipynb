# %%
from hdx.utilities.easy_logging import setup_logging
from hdx.hdx_configuration import Configuration
from hdx.data.dataset import Dataset

# %%
setup_logging()
# Out:
# No logging configuration parameter. Using default.
# Loading logging configuration from: /Users/najwasaqal/anaconda3/envs/Bootcamp/lib/python3.8/site-packages/hdx/utilities/logging_configuration.yml

# %%
Configuration.create(hdx_site='prod', user_agent='A_Quick_Example', hdx_read_only=True)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# <ipython-input-8-8dc5e788e373> in <module>
# ----> 1 Configuration.create(hdx_site='prod', user_agent='A_Quick_Example', hdx_read_only=True)
#
# ~/anaconda3/envs/Bootcamp/lib/python3.8/site-packages/hdx/hdx_configuration.py in create(cls, configuration, remoteckan, **kwargs)
#     538         """
#     539         if cls._configuration is not None:
# --> 540             raise ConfigurationError('Configuration already created!')
#     541         return cls._create(configuration=configuration, remoteckan=remoteckan, **kwargs)
#     542
#
# ConfigurationError: Configuration already created!

# %%
dataset = Dataset.read_from_hdx('acled-conflict-data-for-africa-1997-lastyear')
print(dataset.get_dataset_date())
# Out:
# 2017-01-01

# %%
 datasets = Dataset.search_in_hdx('ACLED', rows=10)
 print(datasets)
 resources = Dataset.get_all_resources(datasets)
 print(resources)
# Out:
# [{'data_update_frequency': '7', 'license_title': 'Other', 'maintainer': '8b84230c-e04a-43ec-99e5-41307a203a2f', 'relationships_as_object': [], 'private': False, 'dataset_date': '01/01/1997-12/31/2020', 'num_tags': 4, 'solr_additions': '{"countries": ["Zimbabwe"]}', 'id': 'e5789990-2442-42d5-b06d-5c9aa3a914eb', 'metadata_created': '2018-02-06T00:07:40.470569', 'archived': False, 'caveats': 'ACLED has several rules about fatalities numbers, sourcing and reporting.\n\n1. ACLED does not have a fatality threshold for event inclusion. This means that conflict and demonstration events in ACLED do not have to produce any fatalities in order to be included as a valid event. We use no arbitrary number of deaths to define a conflict.\n2. ACLED reports fatalities only when a reputable source has relayed that information. Further, researchers seek out information to triangulate – where and when possible – the numbers from any report.\n3. ACLED uses the most conservative estimate available, and will revise and correct the totals – upward or downward – when better information comes available.\n\nACLED advises caution in using all fatality numbers from its, or any other conflict data source. Fatality information is the most biased, and least accurate, part of any conflict report and extreme caution should be employed when using any fatality number to show patterns.', 'metadata_modified': '2020-12-09T01:08:19.420825', 'title': 'Zimbabwe - Conflict Data', 'subnational': '1', 'state': 'active', 'license_other': '**Background**  \nNon-Commercial Licenses - ACLED’s full dataset is available for use free of charge by non-commercial entities and organizations (e.g., non-profit organizations, government agencies, academic institutions) using the data for non-commercial purposes, subject to these Terms of Use. Non-commercial licenses may also be granted to for-profit media outlets or journalists citing ACLED’s content in works of journalism; provided that such works are made available to the general public and benefit public discourse on the topic, subject to ACLED’s prior, written approval.  \nCommercial Licenses - All other commercial exploitation of ACLED content (including, but not limited to, any sale, licensing, sublicensing, or other distribution of the data, in whole or in part, or any incorporation of the data or analysis, in whole or in part, in a product for sale, license, sublicense, or other distribution, to third parties for profit) is prohibited, except as expressly agreed by ACLED in a written Commercial License Agreement executed by ACLED and the licensee. Commercial entities seeking a commercial license to use the full ACLED dataset must submit a request to ACLED at [admin@acleddata.com](mailto:admin@acleddata.com), including the details of the requested use. ACLED reserves the right to withhold approval in its sole discretion. Any approval granted is limited strictly to the use described in the corresponding request and/or approval (which will supersede the request in the case of any inconsistency or conflict).  \n**_Regardless of the type of license, all rights to use or exploit ACLED data or analysis are conditioned on the licensee’s adherence to the Attribution Requirements outlined below._**  \n**_No user is permitted to (i) use ACLED’s data or analysis in any manner that may harm, target, oppress or defame ACLED, the data subjects, or any group or population, or cause any of the foregoing to be harmed, targeted, oppressed or defamed; (ii) provide, permit or allow direct access to any of ACLED’s original/raw data or analysis; (iii) use any of the data or analysis to create, develop, support or provide benchmarking for any dataset, product or platform similar to, or in competition with, or would create a functional substitute for, any of ACLED content, products or platform; and (iv) provide, permit or allow access to any of the data or analysis by ACLED\'s competitors._**  \n**Attribution Requirements**  \n1.  **If using ACLED da ...
# [{'cache_last_updated': None, 'package_id': 'e5789990-2442-42d5-b06d-5c9aa3a914eb', 'dataset_preview_enabled': 'False', 'datastore_active': False, 'id': '46e6c740-beed-47b6-9a75-a6bd8820e05c', 'size': 2474047, 'revision_last_updated': '2020-12-09T01:08:19.418409', 'download_url': 'https://data.humdata.org/dataset/e5789990-2442-42d5-b06d-5c9aa3a914eb/resource/46e6c740-beed-47b6-9a75-a6bd8820e05c/download/conflict_data_zwe.csv', 'state': 'active', 'hash': '', 'description': 'Conflict data with HXL tags', 'format': 'CSV', 'hdx_rel_url': '/dataset/e5789990-2442-42d5-b06d-5c9aa3a914eb/resource/46e6c740-beed-47b6-9a75-a6bd8820e05c/download/conflict_data_zwe.csv', 'last_modified': '2020-12-09T01:08:14.529197', 'url_type': 'upload', 'mimetype': 'text/csv', 'cache_url': None, 'name': 'Conflict Data for Zimbabwe', 'created': '2018-02-06T00:07:40.477195', 'url': 'https://data.humdata.org/dataset/e5789990-2442-42d5-b06d-5c9aa3a914eb/resource/46e6c740-beed-47b6-9a75-a6bd8820e05c/download/conflict_data_zwe.csv', 'mimetype_inner': None, 'position': 0, 'revision_id': '69df7194-ba59-494f-982e-4805dc84da22', 'resource_type': 'file.upload'}, {'cache_last_updated': None, 'package_id': 'e5789990-2442-42d5-b06d-5c9aa3a914eb', 'dataset_preview_enabled': 'True', 'datastore_active': False, 'id': 'f9db1ba2-23a2-4d2b-911f-101f89df32c1', 'size': 123200, 'revision_last_updated': '2020-12-09T01:08:19.418409', 'download_url': 'https://data.humdata.org/dataset/e5789990-2442-42d5-b06d-5c9aa3a914eb/resource/f9db1ba2-23a2-4d2b-911f-101f89df32c1/download/qc_conflict_data_zwe.csv', 'state': 'active', 'hash': '', 'description': 'Cut down data for QuickCharts', 'format': 'CSV', 'hdx_rel_url': '/dataset/e5789990-2442-42d5-b06d-5c9aa3a914eb/resource/f9db1ba2-23a2-4d2b-911f-101f89df32c1/download/qc_conflict_data_zwe.csv', 'last_modified': '2020-12-09T01:08:19.186165', 'url_type': 'upload', 'mimetype': 'text/csv', 'cache_url': None, 'name': 'QuickCharts-Conflict Data for Zimbabwe', 'created': '2020-03-06T10:27:23.899240', 'url': 'https://data.humdata.org/dataset/e5789990-2442-42d5-b06d-5c9aa3a914eb/resource/f9db1ba2-23a2-4d2b-911f-101f89df32c1/download/qc_conflict_data_zwe.csv', 'mimetype_inner': None, 'position': 1, 'revision_id': '69df7194-ba59-494f-982e-4805dc84da22', 'resource_type': 'file.upload'}, {'cache_last_updated': None, 'package_id': '2ca017fd-589d-4308-8ac8-c6f872e68654', 'dataset_preview_enabled': 'False', 'datastore_active': False, 'id': 'd3a8473f-d2ca-45a6-9527-fbed0c6a6785', 'size': 429155, 'revision_last_updated': '2020-12-09T01:08:03.419639', 'download_url': 'https://data.humdata.org/dataset/2ca017fd-589d-4308-8ac8-c6f872e68654/resource/d3a8473f-d2ca-45a6-9527-fbed0c6a6785/download/conflict_data_zmb.csv', 'state': 'active', 'hash': '', 'description': 'Conflict data with HXL tags', 'format': 'CSV', 'hdx_rel_url': '/dataset/2ca017fd-589d-4308-8ac8-c6f872e68654/resource/d3a8473f-d2ca-45a6-9527-fbed0c6a6785/download/conflict_data_zmb.csv', 'last_modified': '2020-12-09T01:07:59.098778', 'url_type': 'upload', 'mimetype': 'text/csv', 'cache_url': None, 'name': 'Conflict Data for Zambia', 'created': '2018-02-06T00:07:35.481520', 'url': 'https://data.humdata.org/dataset/2ca017fd-589d-4308-8ac8-c6f872e68654/resource/d3a8473f-d2ca-45a6-9527-fbed0c6a6785/download/conflict_data_zmb.csv', 'mimetype_inner': None, 'position': 0, 'revision_id': '990c35e5-fc8b-4b80-b25b-fb9b908c659a', 'resource_type': 'file.upload'}, {'cache_last_updated': None, 'package_id': '2ca017fd-589d-4308-8ac8-c6f872e68654', 'dataset_preview_enabled': 'True', 'datastore_active': False, 'id': '5ece3ecc-2c71-40ef-9b96-286f38cc9d03', 'size': 24170, 'revision_last_updated': '2020-12-09T01:08:03.419639', 'download_url': 'https://data.humdata.org/dataset/2ca017fd-589d-4308-8ac8-c6f872e68654/resource/5ece3ecc-2c71-40ef-9b96-286f38cc9d03/download/qc_conflict_data_zmb.csv', 'state': 'active', 'hash': '', 'description': 'Cut down data for QuickCharts', 'format': 'CSV', 'hdx_rel_url': '/dataset/2ca017fd-5 ...
